# %%
answer = []
for number in range(1, 21):
  if number % 3 == 0:
    answer.append("Multiple of 3")
  else:
    answer.append(number)
print(answer)
# Out:
# [1, 2, 'Multiple of 3', 4, 5, 'Multiple of 3', 7, 8, 'Multiple of 3', 10, 11, 'Multiple of 3', 13, 14, 'Multiple of 3', 16, 17, 'Multiple of 3', 19, 20]
